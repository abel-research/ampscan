# %% [markdown]
# # AmpObject Analysis

# %% [markdown]
# This example generates how automated analysis can be performed on the AmpObject

# %%
from AmpScan import AmpObject, analyse
amp = AmpObject("stl_file.stl")

# %% [markdown]
# Running with a slice width of 20mm gives a coarse plot

# %%
fig, ax = analyse.plot_slices(amp, slWidth=25)

# %% [markdown]
# Running with a small slice width gives a finer plot

# %%
fig, ax = analyse.plot_slices(amp, slWidth=10)
